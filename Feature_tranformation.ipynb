# %%
import pandas as pd

# %%
df = pd.read_csv('/content/supershops.csv - supershops.csv.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.shape
# Out:
# (50, 5)

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m = MinMaxScaler(feature_range=(0,1))

# %%
ms = m.fit(df[['Marketing Spend']])
ms
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df['Marketing Spend']=ms.transform(df[['Marketing Spend']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df['Administration'] = m.fit_transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744  471784.10    Dhaka  192261.83
# 1         0.983359        0.761972  443898.53      Ctg  191792.06
# 2         0.927985        0.379579  407934.54  Rangpur  191050.39
# 3         0.873136        0.512998  383199.62    Dhaka  182901.99
# 4         0.859438        0.305328  366168.42  Rangpur  166187.94

# %%
df['Transport']=m.fit_transform(df[['Transport']])

# %%
df['Profit']=m.fit_transform(df[['Profit']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
from sklearn.preprocessing import StandardScaler

# %%
s = StandardScaler()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1['Marketing Spend']=s.fit_transform(df1[['Marketing Spend']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
df1['Administration']=s.fit_transform(df1[['Administration']])

# %%
df1['Transport']=s.fit_transform(df1[['Transport']])

# %%
df1['Profit']=s.fit_transform(df1[['Profit']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.651744   1.000000    Dhaka  1.000000
# 1         1.955860        0.761972   0.940893      Ctg  0.997355
# 2         1.754364        0.379579   0.864664  Rangpur  0.993178
# 3         1.554784        0.512998   0.812235    Dhaka  0.947292
# 4         1.504937        0.305328   0.776136  Rangpur  0.853171

# %%
from sklearn.preprocessing import RobustScaler

# %%
r =  RobustScaler()

# %%
df2['Administration']=r.fit_transform(df2[['Administration']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61        0.345355  471784.10    Dhaka  192261.83
# 1        162597.70        0.697565  443898.53      Ctg  191792.06
# 2        153441.51       -0.524290  407934.54  Rangpur  191050.39
# 3        144372.41       -0.097977  383199.62    Dhaka  182901.99
# 4        142107.34       -0.761543  366168.42  Rangpur  166187.94

# %%
df2['Marketing Spend']=r.fit_transform(df2[['Marketing Spend']])

# %%
df2['Transport']=r.fit_transform(df2[['Transport']])

# %%
df2['Profit']=r.fit_transform(df2[['Profit']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  1.698340
# 1         1.452113        0.697565   1.383714      Ctg  1.688874
# 2         1.303634       -0.524290   1.166654  Rangpur  1.673929
# 3         1.156567       -0.097977   1.017368    Dhaka  1.509736
# 4         1.119836       -0.761543   0.914576  Rangpur  1.172943

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
max = MaxAbsScaler()

# %%
df3['Marketing Spend']=max.fit_transform(df3[['Marketing Spend']])

# %%
df3['Administration']=max.fit_transform(df3[['Administration']])

# %%
df3['Transport']=max.fit_transform(df3[['Transport']])

# %%
df3['Profit']=max.fit_transform(df3[['Profit']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.749527   1.000000    Dhaka  1.000000
# 1         0.983359        0.828805   0.940893      Ctg  0.997557
# 2         0.927985        0.553781   0.864664  Rangpur  0.993699
# 3         0.873136        0.649738   0.812235    Dhaka  0.951317
# 4         0.859438        0.500378   0.776136  Rangpur  0.864383

# %%
for x in df4:
  if(df4[x].dtypes == 'float64'):
    df4[x] = max.fit_transform(df4[[x]])

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.749527   1.000000    Dhaka  1.000000
# 1         0.983359        0.828805   0.940893      Ctg  0.997557
# 2         0.927985        0.553781   0.864664  Rangpur  0.993699
# 3         0.873136        0.649738   0.812235    Dhaka  0.951317
# 4         0.859438        0.500378   0.776136  Rangpur  0.864383

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df7 = df5.copy()

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df8 = df5.copy()
df9 = df5.copy()
df10 = df5.copy()

# %%
for x in df7:
  if(df7[x].dtypes == 'float64'):
    df7[x] = r.fit_transform(df7[[x]])

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  1.698340
# 1         1.452113        0.697565   1.383714      Ctg  1.688874
# 2         1.303634       -0.524290   1.166654  Rangpur  1.673929
# 3         1.156567       -0.097977   1.017368    Dhaka  1.509736
# 4         1.119836       -0.761543   0.914576  Rangpur  1.172943

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ab = MinMaxScaler(feature_range = (0,1))

# %%
for x in df8:
  if(df8[x].dtypes == 'float64'):
    df8[x]=ab.fit_transform(df8[[x]])

# %%
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
df8.describe()
# Out:
#        Marketing Spend  Administration  Transport     Profit
# count        50.000000       50.000000  49.000000  50.000000
# mean          0.445854        0.533345   0.456420   0.548097
# std           0.277608        0.213286   0.253644   0.226974
# min           0.000000        0.000000   0.000000   0.000000
# 25%           0.241527        0.399260   0.284134   0.424920
# 50%           0.441799        0.543661   0.454943   0.525378
# 75%           0.614474        0.712221   0.635327   0.704383
# max           1.000000        1.000000   1.000000   1.000000
